# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_csv = '/Users/daichi/Downloads/ifood/train_labels.csv'
val_csv = '/Users/daichi/Downloads/ifood/val_labels.csv'

# %%
df_train = pd.read_csv(train_csv)

# %%
sns.distplot(df_train.label, kde = True)
plt.show()
